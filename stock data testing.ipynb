# %%
# !pip install yahooquery
# Out:
# ...
#      ---------------------------------------- 49.6/49.6 kB 1.2 MB/s eta 0:00:00
# ...

# %%
from yahooquery import Ticker

# %%
faang=Ticker('GOOGL', asynchronous=True, period='YTD')

# %%
x=faang.history(period='ytd', interval='1d',start=None, end=None)

# %%
x
# Out:
#                         open        high        low      close    volume  \
# symbol date
# GOOGL  2023-01-03  89.589996   91.050003  88.519997  89.120003  28131200
#        2023-01-04  90.349998   90.650002  87.269997  88.080002  34854800
#        2023-01-05  87.470001   87.570000  85.900002  86.199997  27194400
#        2023-01-06  86.790001   87.690002  84.860001  87.339996  41362500
#        2023-01-09  88.360001   90.050003  87.860001  88.019997  29003900
#        2023-01-10  85.980003   88.669998  85.830002  88.419998  30467800
#        2023-01-11  89.180000   91.599998  89.010002  91.519997  26862000
#        2023-01-12  91.480003   91.870003  89.750000  91.129997  30258100
#        2023-01-13  90.849998   92.190002  90.129997  92.120003  26309900
#        2023-01-17  92.059998   92.250000  90.050003  91.290001  32602400
#        2023-01-18  92.139999   92.800003  90.639999  91.120003  29116700
#        2023-01-19  90.720001   93.610001  90.629997  93.050003  37000400
# ...

# %%
import yfinance as yf

# %%
x=yf.download('NVDA')
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - NVDA: No data found for this date range, symbol may be delisted

# %%
# !pip install pandas-datareader
# Out:
# ...
#      -------------------------------------- 109.5/109.5 kB 2.1 MB/s eta 0:00:00
# ...

# %%
import pandas_datareader as pdr

# %%
data = pdr.get_data_yahoo('NVDA')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [45], line 1
# ----> 1 data = pdr.get_data_yahoo('NVDA')
#
# File D:\virtual_env\lib\site-packages\pandas_datareader\data.py:80, in get_data_yahoo(*args, **kwargs)
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#
# File D:\virtual_env\lib\site-packages\pandas_datareader\base.py:253, in _DailyBaseReader.read(self)
#     251 # If a single symbol, (e.g., 'GOOG')
#     252 if isinstance(self.symbols, (string_types, int)):
# --> 253     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254 # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255 elif isinstance(self.symbols, DataFrame):
#
# File D:\virtual_env\lib\site-packages\pandas_datareader\yahoo\daily.py:153, in YahooDailyReader._read_one_data(self, url, params)
# ...

# %%
data = yf.Ticker("NFLX").history(period='10y')

# %%
data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-01-28 00:00:00-05:00   24.644285   25.321428   22.969999   23.158571
# 2013-01-29 00:00:00-05:00   22.590000   24.268572   22.375713   24.160000
# 2013-01-30 00:00:00-05:00   24.784286   25.071428   23.237143   23.957144
# 2013-01-31 00:00:00-05:00   23.871429   24.142857   22.902857   23.605715
# 2013-02-01 00:00:00-05:00   24.285713   24.714287   23.411428   23.542856
# ...                               ...         ...         ...         ...
# 2023-01-19 00:00:00-05:00  322.570007  324.890015  313.390015  315.779999
# 2023-01-20 00:00:00-05:00  336.790009  344.000000  332.630005  342.500000
# 2023-01-23 00:00:00-05:00  341.720001  362.250000  340.630005  357.420013
# 2023-01-24 00:00:00-05:00  357.529999  365.649994  355.140015  363.829987
# 2023-01-25 00:00:00-05:00  360.570007  368.899994  358.500000  367.959991
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
data = yf.Ticker("META")

# %%
type(data.history(period='20y'))
# Out:
# pandas.core.frame.DataFrame

# %%
def get_historical_data(stock_name):
    data = yf.Ticker(stock_name)
    return data.history(period='max')

# %%
x=get_historical_data('TCS.NS')

# %%
x.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
x[x['Dividends']==67.000]
# Out:
#                              Open    High          Low        Close   Volume  \
# Date
# 2023-01-16 00:00:00+05:30  3317.0  3353.0  3298.050049  3334.050049  1843607
#
#                            Dividends  Stock Splits
# Date
# 2023-01-16 00:00:00+05:30       67.0           0.0
